# %%
import rag_helper as rh
lib_path = "../querylib_20250825.db"
results = rh.match(
    file=lib_path, 
    query="How many patients had a biopsy?", 
    k=3
)

# %%
results
# Out:
#    INDEX QUESTION_TYPE                                           QUESTION  \
# 0    217            QA                        How many distinct patients?
# 1     76            QA  How many patient were admitted to hospital wit...
# 2     69            QA  How many Patient have a serum potassium measur...
#
#                                      QUESTION_MASKED  \
# 0                        How many distinct patients?
# 1  How many patient were admitted to hospital wit...
# 2  How many Patient have a MEASUREMENT measuremen...
#
#                                         QUERY_MASKED  \
# 0  SELECT \n    COUNT(DISTINCT person_id) AS tota...
# 1  WITH pulmonary_embolism_patients AS (\n    SEL...
# 2  WITH serum_potassium_measurements AS (\n    SE...
#
#                                     QUERY_EXECUTABLE  \
# 0  SELECT \n    COUNT(DISTINCT person_id) AS tota...
# 1  WITH pulmonary_embolism_patients AS (\n    SEL...
# 2  WITH serum_potassium_measurements AS (\n    SE...
#
# ...
